# %%
import pandas

# %%
dataset = pandas.read_excel("md_1219.xlsx")

# %%
import pandas as pd

# %%
dataset = pd.read_excel("md_1219.xlsx")

# %%
dataset.head()
# Out:
#         Date            Machine_ID Assembly_Line_No  Hydraulic_Pressure  \
# 0 2021-12-31  Makino-L1-Unit1-2013     Shopfloor-L1               71.04
# 1 2021-12-31  Makino-L1-Unit1-2013     Shopfloor-L1              125.33
# 2 2021-12-31  Makino-L3-Unit1-2015     Shopfloor-L3               71.12
# 3 2022-05-31  Makino-L2-Unit1-2015     Shopfloor-L2              139.34
# 4 2022-03-31  Makino-L1-Unit1-2013     Shopfloor-L1               60.51
#
#    Coolant_Pressure  Air_System_Pressure  Coolant_Temperature  \
# 0          6.933725             6.284965                 25.6
# 1          4.936892             6.196733                 35.3
# 2          6.839413             6.655448                 13.1
# 3          4.574382             6.560394                 24.4
# 4          6.893182             6.141238                  4.1
#
#    Hydraulic_Oil_Temperature  Spindle_Bearing_Temperature  Spindle_Vibration  \
# 0                       46.0                         33.4              1.291
# ...

# %%
dataset.tail(5)
# Out:
#            Date            Machine_ID Assembly_Line_No  Hydraulic_Pressure  \
# 2495 2022-02-01  Makino-L1-Unit1-2013     Shopfloor-L1          112.715506
# 2496 2022-02-01  Makino-L1-Unit1-2013     Shopfloor-L1          103.086653
# 2497 2022-02-01  Makino-L2-Unit1-2015     Shopfloor-L2          118.643165
# 2498 2022-02-01  Makino-L3-Unit1-2015     Shopfloor-L3          145.855859
# 2499 2022-02-01  Makino-L2-Unit1-2015     Shopfloor-L2           96.690000
#
#       Coolant_Pressure  Air_System_Pressure  Coolant_Temperature  \
# 2495          5.220885             6.196610                 22.3
# 2496          5.211886             7.074653                 11.9
# 2497          5.212991             6.530049                  4.5
# 2498          5.207777             6.402655                 12.2
# 2499          5.936610             7.109355                  NaN
#
#       Hydraulic_Oil_Temperature  Spindle_Bearing_Temperature  \
# ...

# %%
import seaborn as sns

# %%
dataset.columns
# Out:
# Index(['Date', 'Machine_ID', 'Assembly_Line_No', 'Hydraulic_Pressure',
#        'Coolant_Pressure', 'Air_System_Pressure', 'Coolant_Temperature',
#        'Hydraulic_Oil_Temperature', 'Spindle_Bearing_Temperature',
#        'Spindle_Vibration', 'Tool_Vibration', 'Spindle_Speed', 'Voltage',
#        'Torque', 'Cutting', 'Downtime'],
#       dtype='object')

# %%
dataset[['Spindle_Speed','Voltage','Torque','Cutting']]
# Out:
#       Spindle_Speed  Voltage     Torque  Cutting
# 0           25892.0    335.0  24.055326     3.58
# 1           19856.0    368.0  14.202890     2.68
# 2           19851.0    325.0  24.049267     3.55
# 3           18461.0    360.0  25.860029     3.55
# 4           26526.0    354.0  25.515874     3.55
# ...             ...      ...        ...      ...
# 2495        20974.0    282.0  22.761610     2.72
# 2496        20951.0    319.0  22.786597     2.94
# 2497        20958.0    335.0  22.778987      NaN
# 2498        20935.0    376.0  22.804012     2.79
# 2499        23576.0    385.0  24.409551     3.55
#
# [2500 rows x 4 columns]

# %%
import seaborn as sns

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2495    False
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# Length: 2500, dtype: bool

# %%
dataset.drop_duplicates()
# Out:
#            Date            Machine_ID Assembly_Line_No  Hydraulic_Pressure  \
# 0    2021-12-31  Makino-L1-Unit1-2013     Shopfloor-L1           71.040000
# 1    2021-12-31  Makino-L1-Unit1-2013     Shopfloor-L1          125.330000
# 2    2021-12-31  Makino-L3-Unit1-2015     Shopfloor-L3           71.120000
# 3    2022-05-31  Makino-L2-Unit1-2015     Shopfloor-L2          139.340000
# 4    2022-03-31  Makino-L1-Unit1-2013     Shopfloor-L1           60.510000
# ...         ...                   ...              ...                 ...
# 2495 2022-02-01  Makino-L1-Unit1-2013     Shopfloor-L1          112.715506
# 2496 2022-02-01  Makino-L1-Unit1-2013     Shopfloor-L1          103.086653
# 2497 2022-02-01  Makino-L2-Unit1-2015     Shopfloor-L2          118.643165
# 2498 2022-02-01  Makino-L3-Unit1-2015     Shopfloor-L3          145.855859
# 2499 2022-02-01  Makino-L2-Unit1-2015     Shopfloor-L2           96.690000
#
#       Coolant_Pressure  Air_System_Pressure  Coolant_Temperature  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Date                            0
# Machine_ID                      0
# Assembly_Line_No                0
# Hydraulic_Pressure             10
# Coolant_Pressure               19
# Air_System_Pressure            17
# Coolant_Temperature            13
# Hydraulic_Oil_Temperature      16
# Spindle_Bearing_Temperature     7
# Spindle_Vibration              11
# Tool_Vibration                 11
# Spindle_Speed                   6
# Voltage                         6
# Torque                         21
# Cutting                         7
# Downtime                        0
# dtype: int64

# %%
[features for features in dataset.columns if dataset[features].isnull().sum()>0]
# Out:
# ['Hydraulic_Pressure',
#  'Coolant_Pressure',
#  'Air_System_Pressure',
#  'Coolant_Temperature',
#  'Hydraulic_Oil_Temperature',
#  'Spindle_Bearing_Temperature',
#  'Spindle_Vibration',
#  'Tool_Vibration',
#  'Spindle_Speed',
#  'Voltage',
#  'Torque',
#  'Cutting']

# %%
# %matplotlib inline

# %%
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
##to check data typesdataset.dtypes
dataset.dtypes
# Out:
# Date                           datetime64[ns]
# Machine_ID                             object
# Assembly_Line_No                       object
# Hydraulic_Pressure                    float64
# Coolant_Pressure                      float64
# Air_System_Pressure                   float64
# Coolant_Temperature                   float64
# Hydraulic_Oil_Temperature             float64
# Spindle_Bearing_Temperature           float64
# Spindle_Vibration                     float64
# Tool_Vibration                        float64
# Spindle_Speed                         float64
# Voltage                               float64
# Torque                                float64
# Cutting                               float64
# Downtime                               object
# dtype: object

# %%
dataset.columns
# Out:
# Index(['Date', 'Machine_ID', 'Assembly_Line_No', 'Hydraulic_Pressure',
#        'Coolant_Pressure', 'Air_System_Pressure', 'Coolant_Temperature',
#        'Hydraulic_Oil_Temperature', 'Spindle_Bearing_Temperature',
#        'Spindle_Vibration', 'Tool_Vibration', 'Spindle_Speed', 'Voltage',
#        'Torque', 'Cutting', 'Downtime'],
#       dtype='object')

# %%
dataset.Downtime.value_counts()
# Out:
# Downtime
# Machine_Failure       1265
# No_Machine_Failure    1235
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
##observations:1265 machines are failed
1235 machines are non failed machines
# Out:
#   Cell In[29], line 2
#     1235 machines are non failed machines
#          ^
# SyntaxError: invalid syntax

# %%
dataset.dtypes
# Out:
# Date                           datetime64[ns]
# Machine_ID                             object
# Assembly_Line_No                       object
# Hydraulic_Pressure                    float64
# Coolant_Pressure                      float64
# Air_System_Pressure                   float64
# Coolant_Temperature                   float64
# Hydraulic_Oil_Temperature             float64
# Spindle_Bearing_Temperature           float64
# Spindle_Vibration                     float64
# Tool_Vibration                        float64
# Spindle_Speed                         float64
# Voltage                               float64
# Torque                                float64
# Cutting                               float64
# Downtime                               object
# dtype: object

# %%
x = catg = dataset.select_dtypes("object")
y = cont = dataset.select_dtypes("float")

# %%
x.head()
# Out:
#              Machine_ID Assembly_Line_No         Downtime
# 0  Makino-L1-Unit1-2013     Shopfloor-L1  Machine_Failure
# 1  Makino-L1-Unit1-2013     Shopfloor-L1  Machine_Failure
# 2  Makino-L3-Unit1-2015     Shopfloor-L3  Machine_Failure
# 3  Makino-L2-Unit1-2015     Shopfloor-L2  Machine_Failure
# 4  Makino-L1-Unit1-2013     Shopfloor-L1  Machine_Failure

# %%
y.head()
# Out:
#    Hydraulic_Pressure  Coolant_Pressure  Air_System_Pressure  \
# 0               71.04          6.933725             6.284965
# 1              125.33          4.936892             6.196733
# 2               71.12          6.839413             6.655448
# 3              139.34          4.574382             6.560394
# 4               60.51          6.893182             6.141238
#
#    Coolant_Temperature  Hydraulic_Oil_Temperature  \
# 0                 25.6                       46.0
# 1                 35.3                       47.4
# 2                 13.1                       40.7
# 3                 24.4                       44.2
# 4                  4.1                       47.3
#
#    Spindle_Bearing_Temperature  Spindle_Vibration  Tool_Vibration  \
# 0                         33.4              1.291          26.492
# 1                         34.6              1.382          25.274
# 2                         33.0              1.319          30.608
# ...

# %%
x.drop(['Machine_ID', 'Assembly_Line_No'], axis = 1)
# Out:
#                 Downtime
# 0        Machine_Failure
# 1        Machine_Failure
# 2        Machine_Failure
# 3        Machine_Failure
# 4        Machine_Failure
# ...                  ...
# 2495  No_Machine_Failure
# 2496  No_Machine_Failure
# 2497  No_Machine_Failure
# 2498  No_Machine_Failure
# 2499     Machine_Failure
#
# [2500 rows x 1 columns]

# %%
import seaborn as sns

# %%
y.corr()
# Out:
#                              Hydraulic_Pressure  Coolant_Pressure  \
# Hydraulic_Pressure                     1.000000         -0.074700
# Coolant_Pressure                      -0.074700          1.000000
# Air_System_Pressure                   -0.029783         -0.028886
# Coolant_Temperature                   -0.111303          0.007837
# Hydraulic_Oil_Temperature              0.008647          0.001270
# Spindle_Bearing_Temperature            0.022488         -0.012733
# Spindle_Vibration                     -0.006327          0.005644
# Tool_Vibration                         0.020943         -0.005033
# Spindle_Speed                         -0.120393          0.089118
# Voltage                               -0.004016          0.031202
# Torque                                 0.162734         -0.103770
# Cutting                               -0.222217          0.169249
#
#                              Air_System_Pressure  Coolant_Temperature  \
# ...

# %%
## CORRELATIONAL BETWEEN VLUES
y['Cutting'].corr(y['Torque'])
# Out:
# -0.18018366076535314

# %%
y['Torque'].corr(y['Spindle_Speed'])
# Out:
# -0.19459042194984363

# %%
y['Voltage'].corr(y['Torque'])
# Out:
# 0.006884536369967802

# %%
y['Voltage'].corr(y['Spindle_Speed'])
# Out:
# -0.018401315652382132

# %%
y['Cutting'].corr(y['Voltage'])
# Out:
# -0.04333812583520906

# %%
y['Cutting'].corr(y['Torque'])
# Out:
# -0.18018366076535314

# %%
### 
o<r<_0.19        very low correalated
0.2<_r<_0.39     low correlated
0.4<_r<_0.59     moderate correlated
0.6<_r<_0.79     high correlated
0.8<_r<_1.0      very high correlated

# %%
y.describe()
# Out:
#        Hydraulic_Pressure  Coolant_Pressure  Air_System_Pressure  \
# count         2490.000000       2481.000000          2483.000000
# mean           101.409084          4.947058             6.499275
# std             30.289301          0.997357             0.407279
# min            -14.326454          0.325000             5.063480
# 25%             76.355000          4.462464             6.217987
# 50%             96.763486          4.939960             6.505191
# 75%            126.415727          5.518401             6.780550
# max            191.000000         11.350000             7.973992
#
#        Coolant_Temperature  Hydraulic_Oil_Temperature  \
# count          2487.000000                2484.000000
# mean             18.555368                  47.618317
# std               8.553228                   3.768674
# min               4.100000                  35.200000
# 25%              10.400000                  45.100000
# ...

# %%
plt.figure(figsize=(5,2))
plot = sns.heatmap(y.corr().round(), annot = True)
